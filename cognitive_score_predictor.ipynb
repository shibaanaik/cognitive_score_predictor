# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cognitive_performance.csv")

# %%
df.head()
# Out:
#   User_ID  Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 0      U1   57  Female             6.5             3  Non-Vegetarian
# 1      U2   39  Female             7.6             9  Non-Vegetarian
# 2      U3   26    Male             8.2             6      Vegetarian
# 3      U4   32    Male             7.8             9      Vegetarian
# 4      U5   50    Male             9.7             2  Non-Vegetarian
#
#    Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 0                6.5             Medium               41         583.33
# 1               10.8               High              214         368.24
# 2                5.7                Low              429         445.21
# 3                8.3                Low              464         286.33
# 4               11.3             Medium              365         237.65
#
#    Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# 0                 65            36.71               39.77
# ...

# %%
df.tail()
# Out:
#       User_ID  Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 79995  U79996   55    Male             7.8             9  Non-Vegetarian
# 79996  U79997   35  Female             9.8             6      Vegetarian
# 79997  U79998   32  Female             7.3            10  Non-Vegetarian
# 79998  U79999   34    Male             8.7             8      Vegetarian
# 79999  U80000   41  Female             7.9             7      Vegetarian
#
#        Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 79995                9.4                Low              157         312.34
# 79996                6.5             Medium              130         290.17
# 79997                7.5                Low              462         249.57
# 79998                7.2             Medium               96         319.48
# 79999                2.0             Medium               27         263.21
#
#        Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# ...

# %%
df.shape
# Out:
# (80000, 13)

# %%
df.isnull().sum()
# Out:
# User_ID               0
# Age                   0
# Gender                0
# Sleep_Duration        0
# Stress_Level          0
# Diet_Type             0
# Daily_Screen_Time     0
# Exercise_Frequency    0
# Caffeine_Intake       0
# Reaction_Time         0
# Memory_Test_Score     0
# Cognitive_Score       0
# AI_Predicted_Score    0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df=df.drop(columns='User_ID')

# %%
df.head()
# Out:
#    Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 0   57  Female             6.5             3  Non-Vegetarian
# 1   39  Female             7.6             9  Non-Vegetarian
# 2   26    Male             8.2             6      Vegetarian
# 3   32    Male             7.8             9      Vegetarian
# 4   50    Male             9.7             2  Non-Vegetarian
#
#    Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 0                6.5             Medium               41         583.33
# 1               10.8               High              214         368.24
# 2                5.7                Low              429         445.21
# 3                8.3                Low              464         286.33
# 4               11.3             Medium              365         237.65
#
#    Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# 0                 65            36.71               39.77
# ...

# %%
sns.countplot(x='Diet_Type',data=df)
# Out:
# <Axes: xlabel='Diet_Type', ylabel='count'>

# %%
df['Diet_Type'].value_counts()
# Out:
# Diet_Type
# Non-Vegetarian    47986
# Vegetarian        24136
# Vegan              7878
# Name: count, dtype: int64

# %%
df['Exercise_Frequency'].value_counts()
# Out:
# Exercise_Frequency
# Medium    31990
# Low       31896
# High      16114
# Name: count, dtype: int64

# %%
df[df['Caffeine_Intake']>450]
# Out:
#        Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 3       32    Male             7.8             9      Vegetarian
# 19      26    Male             5.8             2  Non-Vegetarian
# 25      32  Female             4.1             6           Vegan
# 28      46  Female             7.3             8      Vegetarian
# 48      54    Male             5.8             2  Non-Vegetarian
# ...    ...     ...             ...           ...             ...
# 79962   39    Male             8.0             5      Vegetarian
# 79973   19  Female             7.1             8  Non-Vegetarian
# 79982   37    Male             5.3             3  Non-Vegetarian
# 79994   49    Male             8.0             5  Non-Vegetarian
# 79997   32  Female             7.3            10  Non-Vegetarian
#
#        Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 3                    8.3                Low              464         286.33
# ...

# %%
df[df['Caffeine_Intake']>450].count()
# Out:
# Age                   7784
# Gender                7784
# Sleep_Duration        7784
# Stress_Level          7784
# Diet_Type             7784
# Daily_Screen_Time     7784
# Exercise_Frequency    7784
# Caffeine_Intake       7784
# Reaction_Time         7784
# Memory_Test_Score     7784
# Cognitive_Score       7784
# AI_Predicted_Score    7784
# dtype: int64

# %%
df.head()
# Out:
#    Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 0   57  Female             6.5             3  Non-Vegetarian
# 1   39  Female             7.6             9  Non-Vegetarian
# 2   26    Male             8.2             6      Vegetarian
# 3   32    Male             7.8             9      Vegetarian
# 4   50    Male             9.7             2  Non-Vegetarian
#
#    Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 0                6.5             Medium               41         583.33
# 1               10.8               High              214         368.24
# 2                5.7                Low              429         445.21
# 3                8.3                Low              464         286.33
# 4               11.3             Medium              365         237.65
#
#    Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# 0                 65            36.71               39.77
# ...

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender']=df['Gender'].replace({
    'Female':0, 'Male':1 ,"Other":2
})
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_19440\2387418521.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']=df['Gender'].replace({

# %%
df.head()
# Out:
#    Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 0   57       0             6.5             3  Non-Vegetarian
# 1   39       0             7.6             9  Non-Vegetarian
# 2   26       1             8.2             6      Vegetarian
# 3   32       1             7.8             9      Vegetarian
# 4   50       1             9.7             2  Non-Vegetarian
#
#    Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 0                6.5             Medium               41         583.33
# 1               10.8               High              214         368.24
# 2                5.7                Low              429         445.21
# 3                8.3                Low              464         286.33
# 4               11.3             Medium              365         237.65
#
#    Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# 0                 65            36.71               39.77
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Diet_Type']=le.fit_transform(df['Diet_Type'])

# %%
df.head()
# Out:
#    Age  Gender  Sleep_Duration  Stress_Level  Diet_Type  Daily_Screen_Time  \
# 0   57       0             6.5             3          0                6.5
# 1   39       0             7.6             9          0               10.8
# 2   26       1             8.2             6          2                5.7
# 3   32       1             7.8             9          2                8.3
# 4   50       1             9.7             2          0               11.3
#
#   Exercise_Frequency  Caffeine_Intake  Reaction_Time  Memory_Test_Score  \
# 0             Medium               41         583.33                 65
# 1               High              214         368.24                 58
# 2                Low              429         445.21                 49
# 3                Low              464         286.33                 94
# 4             Medium              365         237.65                 62
#
#    Cognitive_Score  AI_Predicted_Score
# 0            36.71               39.77
# ...

# %% [markdown]
# non veg-0,vegan-1,vegeratian-2

# %%
df['Exercise_Frequency']=le.fit_transform(df['Exercise_Frequency'])

# %%
df.head()
# Out:
#    Age  Gender  Sleep_Duration  Stress_Level  Diet_Type  Daily_Screen_Time  \
# 0   57       0             6.5             3          0                6.5
# 1   39       0             7.6             9          0               10.8
# 2   26       1             8.2             6          2                5.7
# 3   32       1             7.8             9          2                8.3
# 4   50       1             9.7             2          0               11.3
#
#    Exercise_Frequency  Caffeine_Intake  Reaction_Time  Memory_Test_Score  \
# 0                   2               41         583.33                 65
# 1                   0              214         368.24                 58
# 2                   1              429         445.21                 49
# 3                   1              464         286.33                 94
# 4                   2              365         237.65                 62
#
#    Cognitive_Score  AI_Predicted_Score
# ...

# %% [markdown]
# medium-2,high-0,low-1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 80000 non-null  int64
#  1   Gender              80000 non-null  int64
#  2   Sleep_Duration      80000 non-null  float64
#  3   Stress_Level        80000 non-null  int64
#  4   Diet_Type           80000 non-null  int64
#  5   Daily_Screen_Time   80000 non-null  float64
#  6   Exercise_Frequency  80000 non-null  int64
#  7   Caffeine_Intake     80000 non-null  int64
#  8   Reaction_Time       80000 non-null  float64
#  9   Memory_Test_Score   80000 non-null  int64
#  10  Cognitive_Score     80000 non-null  float64
#  11  AI_Predicted_Score  80000 non-null  float64
# dtypes: float64(5), int64(7)
# memory usage: 7.3 MB

# %%
df.describe()
# Out:
#                 Age        Gender  Sleep_Duration  Stress_Level     Diet_Type  \
# count  80000.000000  80000.000000    80000.000000  80000.000000  80000.000000
# mean      38.525525      0.560875        7.005332      5.493762      0.701875
# std       12.101876      0.572842        1.734435      2.865308      0.901475
# min       18.000000      0.000000        4.000000      1.000000      0.000000
# 25%       28.000000      0.000000        5.500000      3.000000      0.000000
# 50%       39.000000      1.000000        7.000000      5.000000      0.000000
# 75%       49.000000      1.000000        8.500000      8.000000      2.000000
# max       59.000000      2.000000       10.000000     10.000000      2.000000
#
#        Daily_Screen_Time  Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# count       80000.000000        80000.000000     80000.000000   80000.000000
# mean            6.504646            1.198450       248.988213     399.973579
# ...

# %%
df=df.drop(columns='AI_Predicted_Score')

# %%
df.head()
# Out:
#    Age  Gender  Sleep_Duration  Stress_Level  Diet_Type  Daily_Screen_Time  \
# 0   57       0             6.5             3          0                6.5
# 1   39       0             7.6             9          0               10.8
# 2   26       1             8.2             6          2                5.7
# 3   32       1             7.8             9          2                8.3
# 4   50       1             9.7             2          0               11.3
#
#    Exercise_Frequency  Caffeine_Intake  Reaction_Time  Memory_Test_Score  \
# 0                   2               41         583.33                 65
# 1                   0              214         368.24                 58
# 2                   1              429         445.21                 49
# 3                   1              464         286.33                 94
# 4                   2              365         237.65                 62
#
#    Cognitive_Score
# 0            36.71
# 1            54.35
# ...

# %% [markdown]
# # training and testing

# %%
X=df.drop(columns='Cognitive_Score')
y=df['Cognitive_Score']

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model1.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Absolute Error (MAE): 5.691802299060193
# Mean Squared Error (MSE): 35.94896655383352
# R-squared (R²): 0.9319287790591448

# %%
import joblib
joblib.dump(model1,'cognitive_score_predictor.pkl')
# Out:
# ['cognitive_score_predictor.pkl']
